# %%
import pandas as pd
import numpy as np
dussen_data1=pd.read_csv("C:\Cricket\MS_Dhoni.csv")
dussen_data1.head()
# Out:
#      SID    MID  CHASE  WON  OVER  TOTRUNS  TOTWKTS         CSR  RUNS  BALLS  \
# 0  61163  64914      0    1    42      180        6    0.000000     0      1
# 1  61163  64916      1    0    34      131        5    0.000000     0      4
# 2  61163  64916      1    0    35      138        5   20.000000     1      5
# 3  61163  64916      1    0    36      145        5   85.714286     6      7
# 4  61163  64916      1    0    37      154        5  120.000000    12     10
#
#    ...      OBCSR    TGT       RRR  OUT  DELTASR       CRR  \
# 0  ...   0.000000    NaN  0.000000    1      0.0  4.285714
# 1  ...  86.842105  230.0  6.187500    0      0.0  3.852941
# 2  ...  90.697674  230.0  6.133333    0    100.0  3.942857
# 3  ...  87.234043  230.0  6.071429    0    250.0  4.027778
# 4  ...  88.000000  230.0  5.846154    0    200.0  4.162162
#
#                       SERIES_NAME  OPPOSITION FINISHED START
# 0  India in Bangladesh ODI Series  Bangladesh        1     1
# ...

# %%
for id in dussen_data1[(dussen_data1["RRR"] >= 6) & (dussen_data1["OVER"]>45) & (dussen_data1["WON"]==1)].MID.unique():
    dussen_data1[(dussen_data1["MID"]==id) & (dussen_data1["OVER"]>45)].OVER
#Condition ordering issue here see [7] for proper conditions

# %%
#dussen_data1[(dussen_data1["RRR"] >= 6) & (dussen_data1["OVER"]>40) & (dussen_data1["WON"]==1)].MID.unique()
dussen_data1[(dussen_data1["RRR"] >= 6) & (dussen_data1["OVER"]>30) & dussen_data1["TGT"]>299].MID.unique()
#Condition ordering issue here see [7] for proper conditions
# Out:
# array([], dtype=int64)

# %%
dussen_data1[(dussen_data1["MID"]==521220) & (dussen_data1["OVER"]>45)].OVER
# Out:
# 2444    46
# 2445    47
# 2446    48
# 2447    49
# 2448    50
# Name: OVER, dtype: int64

# %%
dussen_data1[(dussen_data1["MID"]==215449) & (dussen_data1["OVER"]>40)].CSR
dussen_data1[(dussen_data1["MID"]==215449) & (dussen_data1["OVER"]>40)].OBCSR
# Out:
# 127    66.666667
# 128    53.846154
# 129    53.846154
# Name: OBCSR, dtype: float64

# %%
dussen_data1[(dussen_data1["TGT"]>299) & (dussen_data1["RRR"] >= 6) & (dussen_data1["OVER"]>30)].MID.unique()
#dussen_data1[(dussen_data1["RRR"] >= 6) & (dussen_data1["OVER"]>40) & (dussen_data1["TGT"]>299)].MID.unique()
# Out:
# array([ 258476,  297794,  297798,  297805,  291368,  345471,  335356,
#         386534,  456668,  565812,  647249,  647259,  648651,  667645,
#         667649,  656493,  903593,  903601,  895813,  895815, 1034823,
#        1119499, 1119547, 1144520], dtype=int64)

# %%
#dussen_data1[(dussen_data1["MID"]==258476) & (dussen_data1["BALLS"] > 19) ].WON.iloc[0]
dussen_data1[(dussen_data1["MID"]==258476)& (dussen_data1["TGT"]>299) & (dussen_data1["RRR"] >= 6) & (dussen_data1["OVER"]>30)]#.iloc[:,:]
#258476 is missing dismissal entry, fix this.
# Out:
#         SID     MID  CHASE  WON  OVER  TOTRUNS  TOTWKTS        CSR  RUNS  \
# 842  258453  258476      1    1    36      216        4   0.000000     0
# 843  258453  258476      1    1    37      218        4  20.000000     1
# 844  258453  258476      1    1    38      225        4  42.857143     3
# 845  258453  258476      1    1    39      227        4  38.461538     5
# 846  258453  258476      1    1    40      232        4  40.000000     6
# 847  258453  258476      1    1    41      235        5  41.176471     7
# 848  258453  258476      1    1    42      245        5  63.157895    12
# 849  258453  258476      1    1    43      253        5  59.090909    13
# 850  258453  258476      1    1    44      261        5  64.000000    16
# 851  258453  258476      1    1    45      269        5  75.862069    22
# 852  258453  258476      1    1    46      275        5  76.666667    23
# 853  258453  258476      1    1    47      290        5  97.058824    33
# ...

# %%
#dussen_data1[(dussen_data1["MID"]==258476)& (dussen_data1["TGT"]>299) & (dussen_data1["RRR"] >= 6) \
             #& (dussen_data1["OVER"]>30)].iloc[:,:2]
dussen_data1[(dussen_data1["MID"]==258476)& (dussen_data1["TGT"]>299) & (dussen_data1["RRR"] >= 6) & (dussen_data1["OVER"]>30)].loc[:"CSR"]
# Out:
#         SID     MID  CHASE  WON  OVER  TOTRUNS  TOTWKTS        CSR  RUNS  \
# 843  258453  258476      1    1    36      216        4   0.000000     0
# 844  258453  258476      1    1    37      218        4  20.000000     1
# 845  258453  258476      1    1    38      225        4  42.857143     3
# 846  258453  258476      1    1    39      227        4  38.461538     5
# 847  258453  258476      1    1    40      232        4  40.000000     6
# 848  258453  258476      1    1    41      235        5  41.176471     7
# 849  258453  258476      1    1    42      245        5  63.157895    12
# 850  258453  258476      1    1    43      253        5  59.090909    13
# 851  258453  258476      1    1    44      261        5  64.000000    16
# 852  258453  258476      1    1    45      269        5  75.862069    22
# 853  258453  258476      1    1    46      275        5  76.666667    23
# 854  258453  258476      1    1    47      290        5  97.058824    33
# ...

# %%
#dussen_data1.loc[(dussen_data1["MID"]==258476)& (dussen_data1["TGT"]>299) & (dussen_data1["RRR"] >= 6) \
#                 & (dussen_data1["BALLS"]>19) & (dussen_data1["OVER"]>30),["OVER","CSR","OBSCR"]].plot()
#X-AXIS is Row number finally figured it out... :D
# This is to put limit of 20 balls for other player as well.
dussen_data1.loc[(dussen_data1["MID"]==258476)& (dussen_data1["TGT"]>299) & (dussen_data1["RRR"] >= 6) \
                 & (dussen_data1["BALLS"]>19) & (dussen_data1["OBALLS"]>19) & (dussen_data1["OVER"]>30),["OVER","CSR","OBCSR"]].plot()

# %%
#tempdf=dussen_data1.loc[(dussen_data1["MID"]==258476)& (dussen_data1["TGT"]>299) & (dussen_data1["RRR"] >= 6) \
                 #& (dussen_data1["BALLS"]>19) & (dussen_data1["OVER"]>30),["OVER","CSR","OBSCR"]]
#tempdf
#With limiting OBALLS to 20 as well.
tempdf=dussen_data1.loc[(dussen_data1["MID"]==258476)& (dussen_data1["TGT"]>299) & (dussen_data1["RRR"] >= 6)&(dussen_data1["BALLS"]>19) & (dussen_data1["OBALLS"]>19) & (dussen_data1["OVER"]>30),["OVER","CSR","OBCSR"]]
tempdf
# Out:
#      OVER        CSR      OBCSR
# 854    47  97.058824  109.52381
# 855    48  94.590000  109.52381

# %% [markdown]
# temdf.index=temodf.OVER

# %%
tempdf.index=tempdf.OVER
tempdf=tempdf.drop("OVER",axis=1)

# %%
tempdf.plot()
#tempdf
#with limiting OBALLS to 20 I get a 47 over entry where CSR fluctuates but OBSCR doesnt so CSR is a line, OBSCR is a fucking dot.

# %%
temparray=[]
dataRow=dussen_data1.loc[(dussen_data1.RRR>10),["OVER","CSR"]]
for entry in dataRow.CSR:
    temparray.append(float(entry))
dummyseries=pd.Series(temparray,index=dataRow.OVER)
dummyseries.plot()

# %%
dussen_data1[dussen_data1.RRR>20]
#No evidence of stat padding
# Out:
#           SID      MID  CHASE  WON  OVER  TOTRUNS  TOTWKTS         CSR  RUNS  \
# 910    297425   297794      1    0    46      213        9   62.962963    51
# 911    297425   297794      1    0    47      215        9   60.465116    52
# 912    297425   297794      1    0    48      215       10   65.910000    58
# 2699   589304   589309      1    0    45      142        9   44.594595    33
# 2700   589304   589309      1    0    46      149        9   50.632911    40
# 2701   589304   589309      1    0    47      151        9   48.809524    41
# 2702   589304   589309      1    0    48      165       10   60.674157    54
# 2703   589304   589309      1    0    48      165       10   60.670000    54
# 3060   667635   667649      1    0    44      181        7   66.197183    47
# 3061   667635   667649      1    0    45      181        8   65.280000    47
# 3878  1119530  1119547      1    0    45      213        7   67.924528    36
# ...

# %%
#dussen_data1.loc[(dussen_data1.CHASE==0) & (dussen_data1.OVER>44),["OVER","CSR","OBSCR"]].plot()
import seaborn as sns
import matplotlib.pyplot as plot
sns.set()
df1=dussen_data1.loc[(dussen_data1.CHASE==0) & (dussen_data1.OVER>44),["OVER","CSR","OBCSR"]]
df1.index=df1.OVER
df1=df1.drop("OVER",axis=1)
df1.plot()
plot.show()

# %%
import matplotlib.pyplot as plot

df1=dussen_data1.loc[(dussen_data1.CHASE==1) & (dussen_data1.OVER>44),["OVER","CSR","OBCSR"]]
df1.index=df1.OVER
df1=df1.drop("OVER",axis=1)
df1.plot()
plot.show()

# %%
import matplotlib.pyplot as plot

df1=dussen_data1.loc[(dussen_data1.CHASE==1) & (dussen_data1.OVER>44) & (dussen_data1.BALLS>20),["OVER","CSR","OBCSR"]]
df1.index=df1.OVER
df1=df1.drop("OVER",axis=1)
df1.plot()
plot.show()

# %%
import matplotlib.pyplot as plot

df1=dussen_data1.loc[(dussen_data1.CHASE==0) & (dussen_data1.OVER>44) & (dussen_data1.BALLS>20),["OVER","CSR","OBCSR"]]
df1.index=df1.OVER
df1=df1.drop("OVER",axis=1)
df1.plot()
plot.show()

# %%
dussen_data1[(dussen_data1["TGT"]>299) & (dussen_data1["RRR"] >= 6) & ((dussen_data1["OVER"]>30) & (dussen_data1["OVER"]<35))]
# Out:
#           SID      MID  CHASE  WON  OVER  TOTRUNS  TOTWKTS         CSR  RUNS  \
# 896    297425   297794      1    0    31      155        7   68.181818    30
# 897    297425   297794      1    0    32      161        7   66.666667    30
# 898    297425   297794      1    0    33      167        7   63.265306    31
# 899    297425   297794      1    0    34      171        7   63.461538    33
# 1029   297428   297805      1    0    31      158        5   81.818182     9
# 1030   297428   297805      1    0    32      164        5   83.333333    10
# 1031   297428   297805      1    0    33      172        5   73.333333    11
# 1032   297428   297805      1    0    34      176        5   72.222222    13
# 1130   291340   291368      1    0    31      148        5   54.550000    36
# 1156   345463   345471      1    0    31      183        5   40.000000     2
# 1157   345463   345471      1    0    32      187        6   62.500000     5
# ...

# %%
dussen_data1[(dussen_data1["TGT"]>299) & (dussen_data1["RRR"] >= 6) & (dussen_data1["OVER"]>30) & (dussen_data1["WON"]==1)].MID.unique()
# Out:
# array([258476, 335356, 647259, 895815], dtype=int64)

# %%
dussen_data1[(dussen_data1["TGT"]<200) & (dussen_data1["RRR"] >= 6) & (dussen_data1["OVER"]>30)].MID.unique()
# Out:
# array([1098209], dtype=int64)

# %%
dussen_data1[(dussen_data1["MID"]==1098209)& (dussen_data1["TGT"]<250) & (dussen_data1["RRR"] >= 6) & (dussen_data1["OVER"]>30)]
# Out:
#           SID      MID  CHASE  WON  OVER  TOTRUNS  TOTWKTS        CSR  RUNS  \
# 3643  1098204  1098209      1    0    40      127        5  42.528736    37
# 3644  1098204  1098209      1    0    41      128        5  40.217391    37
# 3645  1098204  1098209      1    0    42      131        5  40.206186    39
# 3646  1098204  1098209      1    0    43      135        5  40.594059    41
# 3647  1098204  1098209      1    0    44      151        5  45.192308    47
# 3648  1098204  1098209      1    0    45      159        5  45.794393    49
# 3649  1098204  1098209      1    0    46      165        6  45.794393    49
# 3650  1098204  1098209      1    0    47      171        6  46.788991    51
# 3651  1098204  1098209      1    0    48      174        7  47.747748    53
# 3652  1098204  1098209      1    0    49      174        8  47.370000    54
#
#       BALLS  ORUNS  OBALLS       OBCSR    TGT       RRR  OUT     DELTASR  \
# ...

# %%
dussen_data1[(dussen_data1["MID"]==518959)]
# Out:
#          SID     MID  CHASE  WON  OVER  TOTRUNS  TOTWKTS        CSR  RUNS  \
# 2498  518940  518959      1    1    35      179        4  20.000000     1
# 2499  518940  518959      1    1    36      181        4  20.000000     2
# 2500  518940  518959      1    1    37      182        4  13.333333     2
# 2501  518940  518959      1    1    38      187        4  27.777778     5
# 2502  518940  518959      1    1    39      194        4  31.578947     6
# 2503  518940  518959      1    1    40      197        4  33.333333     8
# 2504  518940  518959      1    1    41      202        4  35.714286    10
# 2505  518940  518959      1    1    42      209        4  41.935484    13
# 2506  518940  518959      1    1    43      217        4  41.176471    14
# 2507  518940  518959      1    1    44      222        4  46.153846    18
# 2508  518940  518959      1    1    45      230        4  55.813953    24
# 2509  518940  518959      1    1    46      239        4  58.695652    27
# ...

# %%
#dussen_data1.loc[(dussen_data1.CHASE==0) & (dussen_data1.OVER>44),["OVER","CSR","OBSCR"]].plot()
df1=dussen_data1.loc[(dussen_data1.CHASE==0) & (dussen_data1.OVER>44),["OVER","CSR"]]
df1.index=df1.OVER
df1=df1.drop("OVER",axis=1)
df1.plot()

# %%
df1=dussen_data1.loc[(dussen_data1.CHASE==1) & (dussen_data1.OVER>44),["OVER","CSR"]]
df1.index=df1.OVER
df1=df1.drop("OVER",axis=1)
df1.plot()

# %%
df1=dussen_data1.loc[(dussen_data1.CHASE==0) & (dussen_data1.OVER>44),["OVER","OBCSR"]]
df1.index=df1.OVER
df1=df1.drop("OVER",axis=1)
df1.plot()

# %%
df1=dussen_data1.loc[(dussen_data1.CHASE==1) & (dussen_data1.OVER>44),["OVER","OBCSR"]]
df1.index=df1.OVER
df1=df1.drop("OVER",axis=1)
df1.plot()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
df1=dussen_data1.loc[(dussen_data1.CHASE==0) & (dussen_data1.OVER>44),["OVER","CSR","OBCSR"]]
df1.index=df1.OVER
plt.plot(df1.OVER,df1.CSR,df1.OBCSR)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
df1=dussen_data1.loc[(dussen_data1.CHASE==1) & (dussen_data1.OVER>44),["OVER","CSR","OBCSR"]]
df1.index=df1.OVER
plt.plot(df1.OVER,df1.CSR,df1.OBCSR)
plt.show()
